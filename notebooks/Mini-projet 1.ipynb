# %% [markdown]
# # Mini-projet #1
#
# Dans le cadre de ce premier petit projet, vous avez à comparer deux extraits de romans québécois : *L'Oublié* de Laure Conan (1900-1901) et *L'Influence d'un livre* de Philippe Aubert de Gaspé fils (1837). Cette comparaison doit se faire sur la base d'informations extraites grâce à un script Python que vous rédigerez.
#
#
# ### A. Mise en forme
# Votre première tâche est de nettoyer les extraits et de les afficher avec la fontion `print`. Quelques éléments sont à considérer :
# - Les sauts de lignes simples ne correspondent à rien de pertinent du point de vue du texte et doivent être retirés.
# - Les lignes vides correspondent à des sauts de paragraphes et doivent être conservées.
# - Les espaces superflues (en début de ligne, après points, devant virgules) doivent être retirées.
# - Les numéros de lignes, présents dans le deuxième extrait, doivent être retirés.
# - Assurez-vous de bien commenter chaque élément du script afin d'expliquer ce que vous cherchez à faire à chaque étape (utilisez `#`).
#
# ### B. Extraction des données
# Votre deuxième tâche est d'extraire certaines informations des textes :
#
# 1. Le nombre de mots total dans chaque extrait ;
# 2. Le(s) mot(s) le(s) plus long(s) de chaque extrait ;
# 3. La longueur  moyenne des mots dans les deux extraits ;
# 4. La longueur moyenne des phrases dans les deux extraits ;
# 5. Le nombre de mots différents dans chaque extrait (attention aux majuscules; p. ex. « La » doit être traité comme le même mot que « la ») ;
# 6. Les mots utilisés plus d'une fois.
# - Assurez-vous de bien commenter chaque élément du script afin d'expliquer ce que vous cherchez à faire à chaque étape.
#
#
# ### C. Comparaison
# Une fois les informations nécessaires obtenues grâce à votre script, rédigez un court texte comparant les deux extraits. Ce texte peut être placé dans la cellule Markdown fournie plus bas, ou dans un fichier docx/pdf séparé. Si vous utilisez la cellule Markdown, vous n'avez pas à vous soucier des questions de formatage/style.
#
# ### D. Réflexion
# Terminez votre texte avec une brève réflexion sur les limites des fonctions que nous avons vues jusqu'ici.
# - Y a-t-il des aspects des extraits qui sont difficiles à traiter avec les outils dont nous disposons actuellement?
# - Trouvez au moins une question par rapport aux extraits qui ne peut pas être abordée de façon satisfaisante avec ces derniers.
# - Sans entrer dans les détails techniques, proposez une fonction potentielle qui permettrait d'aborder cette question.
#
# ## Modalités :
# - Le script complet au format Jupyter (ipynb) et le texte contenant la comparaison/réflexion (cellule dans le Notebook ou docx/pdf séparé) doivent être remis (par courriel ou sur le portail) au plus tard le 25 septembre 2025.
# - Je vous demande de vous limiter aux fonctionnalités vues en classe pour compléter ce projet.
# - Relisez au besoin la section sur le recours aux IA génératives dans le plan de cours.
# - Pour ce travail, il n'est **pas permis** d'utiliser des lignes de code produites par une IA générative.

# %%
#L'oublié (Laure Conan, 1900-1901)
oublie = '''Ville-Marie n’était encore qu’un champ de 
 bataille bien souvent ensanglanté , mais la sainte 
 colonie , comme l’appelle LeClercq, était 
 définitivement sortie du fort.  

 Sur la Pointe-à-Callières , à travers des champs
 cultivés , on apercevait une trentaine de petites 
 maisons solides , à toit pointu, protégées par des 
 redoutes.   

 Deux de ces redoutes attenaient à l’hôpital bâti 
 sur le coteau et environné d’une haute palissade.   
 L’asile des blessés disparaissait presque 
 entièrement derrière ces grands pieux sinistres ; 
 on n’en voyait guère que le toit surmonté d’un 
 svelte clocher où l’on sonnait le tocsin à chaque 
 attaque des Iroquois.   

 Ce jour-là , il n’y en avait pas eu , mais la 
 besogne administrative avait été lourde.   
 
 Un peu fatigué , Monsieur de Maisonneuve avait 
 ouvert sa fenêtre et jouissait de la fraîcheur du 
 soir , en causant avec son secrétaire , Monsieur de 
 Brigeac.   
 
 Derrière la montagne , le soleil couchant 
 lançait ses derniers feux.   Une splendeur 
 enflammée flottait sur l’île Royale encore 
 presque toute couverte de broussailles ou de 
 grands bois : et , au large , la Notre-Dame se
 balançait comme perdue sur les flots éclatants et 
 déserts.   Mais Maisonneuve n’aimait à regarder 
 que les petits champs des colons et leurs maisons 
 humbles et frustes.'''

# L'influence d'un livre (Philippe Aubert de Gaspé, 1837)
influence = '''01Sur la rive sud du fleuve St-Laurent, dans une plaine 
02qui s’étend jusqu’à une chaîne de montagnes, dont nous 
03ignorons le nom, se trouve une petite chaumière qui n’a 
04rien de remarquable par elle-même ; située au bas d’une 
05colline, sa vue est dérobée aux voyageurs par un bosquet 
06de pins qui la défend contre le vent du nord, si fréquent 
07dans cette partie de la contrée. Autrefois cette misérable 
08cabane était habitée par trois personnes : un homme, son épouse, 
09jeune femme vieillie par le chagrin, et un enfant, fruit de 
10leur union. Cet homme que nous appellerons Charles Amand la 
11possédait au tems dont nous parlons ; en ayant éloigné ses 
12autres habitans afin de vaquer secrètement à des travaux mystérieux 
13auxquels il avait dévoué sa vie. C’était le 15 Août de l’année 
14182— Charles Amand était debout au milieu de l’unique pièce que 
15contenait ce petit édifice presqu’en ruine. D’un côté un méchant 
16lit sans rideau ; vis-à-vis un établi de menuisier, couvert de 
17divers instruments, parmi lesquels on remarquait deux creusets, 
18dont l’un était cassé : aussi, différents minéraux que Charles 
19considérait d’un air pensif sur un âtre ; au côté droit de l’appartement, 
20brûlaient, épars çà et là, quelques morceaux de charbon de terre. 
21Près de l’âtre, sur une table, un mauvais encrier, quelques morceaux 
22de papier et un livre ouvert absorbaient une partie de l’attention 
23de l’Alchimiste moderne ; ce livre était : les ouvrages d’Albert le Petit.'''


# Votre code ici
# Nettoyage texte oublie
# Garder les sauts de paragraphes \n\n avant split
oublie = oublie.replace("\n\n", "@@")
oublie = oublie.replace("\n \n", "@@")
# Diviser le texte en chaîne pour enlever les sauts de lignes simples
for ligne in oublie.split("\n") :
    
    print(ligne)

# Création d'une liste vide puis enlever les espaces superflus au début et à la fin du texte.
lignes_strip = []

for ligne in oublie.split("\n"):
    ligne_strip = ligne.strip()
    print(ligne_strip)
    lignes_strip.append(ligne_strip)
print(lignes_strip)

# Enlever les espaces superflues
lignes_nettoyees = []
for ligne in lignes_strip:
    ligne = ligne.replace(" ,", ",")
    ligne = ligne.replace(" .", ".")
    ligne = ligne.replace(" :", ":")
    ligne = ligne.replace(" ;", ";")
    ligne = ligne.replace(" ?", "?")
    ligne = ligne.replace(" !", "!")
    ligne = ligne.replace(".   ", ". ")
    lignes_nettoyees.append(ligne)
print(lignes_nettoyees)

# Assembler pour que ce ne soit plus en liste

chaîne_oublie = " ".join(lignes_nettoyees)

print(chaîne_oublie)

 
# Remettre les paragraphes

oublie_2 = chaîne_oublie.replace(" @@ ","\n\n")
print(oublie_2)



print("--------------------------------------")
print("--------------------------------------")
print("--------------------------------------")

oublie_final = oublie_2.strip()
print(oublie_final)

print("--------------------------------------")
print("--------------------------------------")
print("--------------------------------------")
# Out:
# Ville-Marie n’était encore qu’un champ de
#  bataille bien souvent ensanglanté , mais la sainte
#  colonie , comme l’appelle LeClercq, était
#  définitivement sortie du fort.  @@ Sur la Pointe-à-Callières , à travers des champs
#  cultivés , on apercevait une trentaine de petites
#  maisons solides , à toit pointu, protégées par des
#  redoutes.   @@ Deux de ces redoutes attenaient à l’hôpital bâti
#  sur le coteau et environné d’une haute palissade.
#  L’asile des blessés disparaissait presque
#  entièrement derrière ces grands pieux sinistres ;
#  on n’en voyait guère que le toit surmonté d’un
#  svelte clocher où l’on sonnait le tocsin à chaque
#  attaque des Iroquois.   @@ Ce jour-là , il n’y en avait pas eu , mais la
#  besogne administrative avait été lourde.   @@ Un peu fatigué , Monsieur de Maisonneuve avait
#  ouvert sa fenêtre et jouissait de la fraîcheur du
#  soir , en causant avec son secrétaire , Monsieur de
#  Brigeac.   @@ Derrière la montagne , le soleil couchant
# ...

# %% [markdown]
# ## Comparaison entre les extraits (cliquez pour modifier cette cellule Markdown)
