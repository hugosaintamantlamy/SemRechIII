# %% [markdown]
# # Exercice 1
#
# Pour faire cet exercice, vous devrez téléchargez le corpus CIDRE (portail, séance 6) et déposer les fichiers sur votre machine.
#
# En mettant ensemble les différents éléments que nous venons de voir, tokenisez le roman *Les Bons Enfants* de la Comtesse de Ségur (CIDRE\Ségur\1861_Les_Bons_Enfants.epub.txt).
#
# Afin de vous assurer que tout a fonctionné :
# - Imprimez les 500 premiers caractères du texte (p. ex. `print(bons_enfants[0:500])`)
# - Imprimez une liste des mots qui contiennent encore une apostrophe
# - Imprimez une liste des mots qui contiennent encore un tiret court

# %%
# VOTRE CODE ICI

# %% [markdown]
# # Exercice 2
#
# En reprenant la logique développée à l'exercice 1, tokenisez le texte *Indiana* de Georges Sand (CIDRE\Sand\1831_Indiana.epub.txt).
#
# Effectuez les tâches suivantes :
# - Comparez le ratio occurrences / types pour les deux textes (nb. mot total divisé par nombre de mots uniques).
# - Trouvez un mot qui se trouve dans *Les Bons Enfants* mais pas dans *Indiana*, et vice versa.
# - Identifiez les 20 mots les plus fréquents dans chaque texte et voyez s'il y a des différences notables.
# - Choisissez trois mots qui se trouvent dans les deux textes et comparez leur fréquence.

# %%
# VOTRE CODE ICI

# %% [markdown]
# # EXERCICE 3 (réflexion)
#
# - Regardez les fréquences lexicales des 50 mots les usités dans *Les Bons Enfants* mais pas dans *Indiana*
# - Parmi ces mots, lesquels sont des mots grammaticaux et lesquels sont des mots lexicaux?
# - Essayez d'imaginer une solution qui permettrait d'écarter les mots grammaticaux afin de se concentrer sur les mots lexicaux, plus pertinents pour les analyses de contenu.
#
# ### Classes lexicales :
# - **Mots grammaticaux (mots-outils)** : déterminants, prépositions, pronoms, conjonctions (classes fermées)
# - **Mots lexicaux** : noms, verbes, adjectifs qualitatifs, adverbes (classes ouvertes)

# %%
# VOTRE CODE ICI
